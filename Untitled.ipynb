# %%
import sys 
import matplotlib.pyplot as plt
import numpy as np
import random

op6 = [
    12.783,
    12.953,
    12.96,
    13.121,
    13.134,
    13.218,
    13.433,
    13.469,
    13.521,
    13.566,
    13.693,
    13.694,
    13.795,
    13.904,
    13.915,
    13.922,
    13.978,
    14.039,
    14.074,
    15.322,
]

op5 = [
    61.074,
    64.175,
    64.191,
    65.143,
    65.748,
    65.924,
    66.588,
    66.892,
    66.994,
    67.095,
    67.222,
    68.232,
    69.613,
    70.122,
    70.736,
    70.818,
    72.039,
    79.491,
    82.687,
    83.046,
]

op4 = [
    4.958,
    6.069,
    6.137,
    6.181,
    6.226,
    6.235,
    6.273,
    6.313,
    6.326,
    6.367,
    6.458,
    6.531,
    6.58,
    6.592,
    6.617,
    6.757,
    6.818,
    6.991,
    7.248,
    7.735,   
]

op3 = [
    26.61,
    28.93,
    28.961,
    29.242,
    30.399,
    30.651,
    30.732,
    32.179,
    32.294,
    32.859,
    33.473,
    35.395,
    35.753,
    37.307,
    38.761,
    39.626,
    39.866,
    43.21,
    47.108,
    51.639,
]

op2 = [
    6.062,
    6.181,
    6.248,
    6.352,
    6.443,
    6.449,
    6.474,
    6.502,
    6.597,
    6.622,
    6.73,
    6.809,
    6.838,
    6.863,
    6.913,
    6.921,
    7.007,
    7.025,
    7.07,
    7.473,
]

op1 = [
    5.35,
    5.92,
    5.93,
    5.97,
    6.03,
    6.14,
    6.16,
    6.17,
    6.18,
    6.24,
    6.24,
    6.26,
    6.26,
    6.3,
    6.3,
    6.36,
    6.37,
    6.44,
    6.48,
    6.53,
]

random.shuffle(op1)
random.shuffle(op2)
random.shuffle(op3)
random.shuffle(op4)
random.shuffle(op5)
random.shuffle(op6)

def plot_op(name, data, colr): 
    # graph t vs 
    points = range(1, 21)

    plt.scatter(points, data, color = colr)
    axes = plt.gca()
    plt.xticks(range(0, 21))
    axes.set_ylim([0,90])

    plt.title(name)
    plt.xlabel('Points')
    plt.ylabel('Time (ms)')
    plt.savefig("plot_time_vs_points.png")
    plt.show()

plot_op('Option 1', op1, 'yellow');
plot_op('Option 2', op2, 'green');
plot_op('Option 3', op3, 'magenta');
plot_op('Option 4', op4, 'red');
plot_op('Option 5', op5, 'pink');
plot_op('Option 6', op6, 'blue');
